# %%
# these are some necessary libs, but feel free to import whatever you need
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from matplotlib import pyplot as plt
import math

# %%
### don't change this
### seed everything for reproducibility
def seed_everything():
    seed = 42
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)

# %% [markdown]
# # Prepare for the Transformer

# %% [markdown]
# ###  Implement a scaled dot product

# %%
def scaled_dot_product(q, k, v):
    d_k = q.size()[-1]
    
    # TODO: put your code below
    # values should be the final output
    # attention should be the n by n attention matrix (the dot product after softmax)
    
    dot_product = torch.matmul(q, k.transpose(-2, -1))
    
    scaled_dot_product = dot_product / torch.sqrt(torch.tensor(d_k, dtype=torch.float32))
    
    attention = F.softmax(scaled_dot_product, dim=-1)

    values = torch.matmul(attention, v)

    #========================#
    return values, attention

# %%
### set what you get
### do not modify this cell
seed_everything()
seq_len, d_k = 3, 2
q = torch.randn(seq_len, d_k)
k = torch.randn(seq_len, d_k)
v = torch.randn(seq_len, d_k)
values, attention = scaled_dot_product(q, k, v)
print("Q\n", q)
print("K\n", k)
print("V\n", v)
print("Values\n", values)
print("Attention\n", attention)
assert attention.shape == (seq_len, seq_len)
# Out:
# Q
#  tensor([[ 0.3367,  0.1288],
#         [ 0.2345,  0.2303],
#         [-1.1229, -0.1863]])
# K
#  tensor([[ 2.2082, -0.6380],
#         [ 0.4617,  0.2674],
#         [ 0.5349,  0.8094]])
# V
#  tensor([[ 1.1103, -1.6898],
#         [-0.9890,  0.9580],
#         [ 1.3221,  0.8172]])
# Values
#  tensor([[ 0.5698, -0.1520],
#         [ 0.5379, -0.0265],
#         [ 0.2246,  0.5556]])
# Attention
#  tensor([[0.4028, 0.2886, 0.3086],
#         [0.3538, 0.3069, 0.3393],
#         [0.1303, 0.4630, 0.4067]])

# %% [markdown]
# ### Try masked scaled-dot product

# %%
def masked_scaled_dot_product(q, k, v, mask):
    # the mask will be in shape n by n, it indicates the interaction between specific pair of tokens need not be considered
    d_k = q.size()[-1]

    # TODO: put your code below
    # values should be the final output
    # attention should be the n by n attention matrix (the dot product after softmax)
    dot_product = torch.matmul(q, k.transpose(-2, -1))

    scaled_dot_product = dot_product / torch.sqrt(torch.tensor(d_k, dtype=torch.float32))

    scaled_dot_product.masked_fill_(mask == 0, float('-inf'))

    attention = F.softmax(scaled_dot_product, dim=-1)

    values = torch.matmul(attention, v)
    
    #========================#
    return values, attention

# %%
### set what you get
### do not modify this cell
seed_everything()
seq_len, d_k = 3, 2
# create a low triangular mask
# looks like this
# 1 0 0
# 1 1 0
# 1 1 1
# this will also be helpful for masked attention in the decoder
mask = torch.tril(torch.ones(seq_len, seq_len)) == 0
q = torch.randn(seq_len, d_k)
k = torch.randn(seq_len, d_k)
v = torch.randn(seq_len, d_k)
values, attention = masked_scaled_dot_product(q, k, v, mask)
print("Q\n", q)
print("K\n", k)
print("V\n", v)
print("Values\n", values)
print("Attention\n", attention)
# Out:
# Q
#  tensor([[ 0.3367,  0.1288],
#         [ 0.2345,  0.2303],
#         [-1.1229, -0.1863]])
# K
#  tensor([[ 2.2082, -0.6380],
#         [ 0.4617,  0.2674],
#         [ 0.5349,  0.8094]])
# V
#  tensor([[ 1.1103, -1.6898],
#         [-0.9890,  0.9580],
#         [ 1.3221,  0.8172]])
# Values
#  tensor([[0.2052, 0.8852],
#         [1.3221, 0.8172],
#         [   nan,    nan]])
# Attention
#  tensor([[0.0000, 0.4833, 0.5167],
#         [0.0000, 0.0000, 1.0000],
#         [   nan,    nan,    nan]])

# %% [markdown]
# ### Positional encoding (from original Transformer)

# %%
class PositionalEncoding(nn.Module):

    def __init__(self, d_model, max_len=5000):
        """
        Inputs
            d_model - Hidden dimensionality of the input.
            max_len - Maximum length of a sequence to expect.
        """
        super().__init__()

        # Create matrix of [SeqLen, HiddenDim] representing the positional encoding for max_len inputs
        pe = torch.zeros(max_len, d_model)
        
        # ==================================== #
        # TODO: put your code below
        

        # ==================================== #
        # register_buffer => Tensor which is not a parameter, but should be part of the modules state.
        # Used for tensors that need to be on the same device as the module.
        # persistent=False tells PyTorch to not add the buffer to the state dict (e.g. when we save the model) 
        self.register_buffer('pe', pe, persistent=False)
        
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))
        
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)

        pe = pe.unsqueeze(0).transpose(0, 1)
        
        
        self.register_buffer('pe', pe, persistent=False)
        
        

    def forward(self, x):
        pe = self.pe[:, :x.size(1)]

        #TODO: put your code below
        x = x + self.pe[:x.size(0), :]
        
        return x

# %%
### visualize the positional encoding and see what you get, do not modify this

pe_block = PositionalEncoding(d_model=48, max_len=100)
pe = pe_block.pe.squeeze().T.cpu().numpy()

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,5))
pos = ax.imshow(pe, cmap="RdGy", extent=(1,pe.shape[1]+1,pe.shape[0]+1,1))
fig.colorbar(pos, ax=ax)
ax.set_xlabel("Position in sequence")
ax.set_ylabel("Hidden dimension")
ax.set_title("Positional encoding over hidden dimensions")
ax.set_xticks([1]+[i*10 for i in range(1,1+pe.shape[1]//10)])
ax.set_yticks([1]+[i*10 for i in range(1,1+pe.shape[0]//10)])
plt.show()

# %% [markdown]
# #  Build your own "GPT" for 1D Burgers' prediction

# %%
### load data, modify this when you have a different path
train_data = np.load('burgers_train.npy')
test_data = np.load('burgers_test.npy')
print(train_data.shape, test_data.shape)
# Out:
# (2048, 40, 100) (128, 40, 100)

# %% [markdown]
# ### Visualize a sequence (optional)

# %%
### You don't have to modify this function
from matplotlib.ticker import FormatStrFormatter

def show_field(field):

    fig, ax = plt.subplots(figsize=(15, 5))
    # mark y axis as time, x axis as space
    ax.set_xlabel('x',fontsize=16)
    ax.set_ylabel('t', fontsize=16)
    ax.set_xlim(0, 50+1e-5)

    ax.set_yticks(np.arange(0, 41, 10), [str(round(f, 2)) for f in np.linspace(0, 1.28, 5)][::-1])
    ax.set_xticks(np.arange(0, 101, 10),[str(round(f, 2)) for f in np.linspace(0, 16, 11)])

    im = ax.imshow(field,cmap='seismic')
    plt.colorbar(im)

    plt.show()

# %%
show_field(train_data[0])

# %%
# take a look at one of the snapshots
plt.plot(np.linspace(0, 16, 100), train_data[0, 20])
plt.gca().set_xlabel('x',fontsize=16)
plt.gca().set_ylabel('u', fontsize=16)
# Out:
# Text(0, 0.5, 'u')

# %% [markdown]
# #### Helper functions (do not modify!)

# %%
### do not modify this cell
### ======================
class SimpleEncoder(nn.Module):
    # for embedding the first 10 time steps of darcy flow
    def __init__(self,
                 input_dim=100,    # we take number of grid points as number of feature for each frame
                 hidden_dim=64,   # hidden dimensionality of the encoder
                 emb_dim=128):
        super().__init__()
        # we use 1d depth-wise convolution to embed the input
        self.net = nn.Sequential(
            nn.Conv1d(input_dim, hidden_dim, kernel_size=1, stride=1, padding=0, groups=4),
            nn.GELU(),   # GELU is a better version of ReLU, for most tasks
            nn.Conv1d(hidden_dim, hidden_dim, kernel_size=1, stride=1, padding=0, groups=8),
            nn.GELU(),
            nn.Conv1d(hidden_dim, hidden_dim, kernel_size=1, stride=1, padding=0, groups=4),
            nn.GELU(),
            nn.Conv1d(hidden_dim, hidden_dim, kernel_size=1, stride=1, padding=0),
            nn.GELU(),
            nn.Conv1d(hidden_dim, emb_dim, kernel_size=1, stride=1, padding=0))

        self.to_out = nn.Sequential(
            nn.LayerNorm(emb_dim),
            nn.Linear(emb_dim, emb_dim),
        )

    def forward(self, x):
        # x will be in shape [b t n], n is number of grid points, but you can think it as feature dimension
        # we need to transpose it to [b n t] for the convolution
        x = x.transpose(1, 2)
        # now we can apply the convolution
        x = self.net(x)
        x = x.transpose(1, 2)
        return self.to_out(x)


class SimpleDecoder(nn.Module):
    # go back from the latent space to the physical space
    def __init__(self,
                 input_dim=128,     # latent dimensionality
                 hidden_dim=64,   # hidden dimensionality of the decoder
                 output_dim=100):
        super().__init__()
        self.ln = nn.LayerNorm(input_dim)
        self.net = nn.Sequential(
            nn.Conv1d(input_dim, hidden_dim, kernel_size=1, stride=1, padding=0),
            nn.GELU(),
            nn.Conv1d(hidden_dim, hidden_dim, kernel_size=1, stride=1, padding=0, groups=4),
            nn.GELU(),
            nn.Conv1d(hidden_dim, output_dim, kernel_size=1, stride=1, padding=0, groups=2),
        )

    def forward(self, x):
        # x will be in shape [b t c]
        x = self.ln(x)
        x = x.transpose(1, 2)
        x =  self.net(x).transpose(1, 2)  # [b t c] again
        return x



class FFN(nn.Module):
    # give to you for free, need to be used in the transformer
    def __init__(self, input_dim=128, hidden_dim=128, output_dim=128):
        super().__init__()
        self.net = nn.Sequential(
            nn.LayerNorm(input_dim),
            nn.Linear(input_dim, hidden_dim),
            nn.GELU(),
            nn.Linear(hidden_dim, output_dim),
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# ### Implement a multi-head self-attention module (with causal mask)

# %%
# you need to implement this
class CausalSelfAttention(nn.Module):

    def __init__(self,
                 dim,
                 dim_head,
                 num_heads,
                 dropout,       # dropout for attention matrix (Q^T K), not input or output
                 max_len=50
                 ):
        super().__init__()
        self.dim = dim
        self.inner_dim = dim_head * num_heads
        self.num_heads = num_heads
        self.dim_head = dim_head

        # ==================================================================
        #TODO: implement the module of the causal self attention

        self.scale = dim_head ** -0.5 
        self.to_qkv = nn.Linear(dim, self.inner_dim * 3, bias=False)

        self.to_out = nn.Linear(self.inner_dim, dim)

        self.dropout = nn.Dropout(dropout)

        self.register_buffer("mask", torch.tril(torch.ones(max_len, max_len)).view(1, 1, max_len, max_len))


        # ==================================================================
        self._init_weights()

    def _init_weights(self):
        # you can implement some weight initialization here (optional), can provide some performance boost when doing it correctly
        nn.init.normal_(self.to_qkv.weight, mean=0, std=0.02)
        nn.init.normal_(self.to_out.weight, mean=0, std=0.02)
        
        #pass

    def forward(self, x):
        # input is in shape [b t c], output is also in shape [b t c]
        B, L, C = x.size() # batch size, sequence length, embedding dimensionality (n_embd)

        # ==================================================================
        #TODO: implement the forward pass of the causal self attention

        qkv = self.to_qkv(x).reshape(B, L, 3, self.num_heads, self.dim_head).permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]  # Each shape: [B, num_heads, L, dim_head]

        # Scaled dot product attention (with causality)
        dots = torch.matmul(q, k.transpose(-2, -1)) * self.scale

        # Apply the mask
        causal_mask = self.mask[:, :, :L, :L]
        dots.masked_fill_(~causal_mask.bool(), float('-inf'))

        # Apply softmax and dropout for normalization and regularization
        attn = self.dropout(F.softmax(dots, dim=-1))

        # Final output
        out = torch.matmul(attn, v)

        # Transpose and reshape to move the head dimension back and combine it with the feature dimension
        out = out.transpose(1, 2).reshape(B, L, -1)

        # Apply the final linear transformation
        out = self.to_out(out)

        return out

# %% [markdown]
# ### Use above attention block to build a PDE-GPT

# %%
### you only have to fill a small part inside the forward function
class PDEGPT(nn.Module):
    def __init__(self,
                 num_layers,    # the only hyperparameter to play with, could start with sth like 6
                 ):
        super().__init__()

        self.transformer = nn.ModuleList([])
        for _ in range(num_layers):
            self.transformer.append(nn.ModuleList([
                nn.LayerNorm(128),
                CausalSelfAttention(dim=128, dim_head=128, num_heads=4, dropout=0.05),
                FFN(input_dim=128, hidden_dim=128, output_dim=128),
            ]))
        self.function_encoder = SimpleEncoder()
        self.function_decoder = SimpleDecoder()
        self.position_embedding =  PositionalEncoding(128, 40)

        # report number of parameters
        print(f"Total number of trainable parameters: {self.get_num_params()}" )

    def get_num_params(self):
        n_params = sum(p.numel() for p in self.parameters() if p.requires_grad)
        return n_params

    def forward(self, seq, noise=True, tstart=0):
        # seq in shape [batch_size, 49, 100] t=49, n=100, think about why it is 49 not 50

        b, t, n = seq.size()
        device = seq.device

        # forward the GPT model itself
        if noise:
            # add random walk noise to the input
            seq = seq + torch.cumsum(torch.randn_like(seq) * 0.003, dim=1)
        x = self.function_encoder(seq)   # [b t n] -> [b t c]
        x = x + self.position_embedding(x) # add position embedding

        for ln, attn_block, ffn in self.transformer:
            # ln: layer normalization
            # attn_block: self attention layer
            # ffn: feed forward network (a two-layer MLP)
            # ===================================================
            # TODO: implement one forward pass of the transformer (do not modify other part of this class)
            x = ln(x)

            x = attn_block(x) + x 

        
            x = ffn(x) + x  
                
            # ===================================================

        x = self.function_decoder(x)   # [b t c] -> [b t n]
            
        return x

    def predict(self, in_seq, predict_steps=30, tstart=0):
        # in_seq will be in shape [batch_size, 10, 100]
        out_seq = torch.zeros(in_seq.size(0), predict_steps, in_seq.size(2)).to(in_seq.device)
        for t in range(predict_steps):
            if self.training:
                shifted_in_seq = self.forward(in_seq, noise=True, tstart=tstart)
            else:
                shifted_in_seq = self.forward(in_seq, noise=False, tstart=tstart)
            in_seq = torch.cat((in_seq, shifted_in_seq[:, -1:]), dim=1)
            out_seq[:, t:t+1] = shifted_in_seq[:, -1:]

        return out_seq

# %% [markdown]
# ### Train the model

# %%
### do not modify this cell!
### ==============================
def train_a_gpt(lr,
                num_layers,
                batch_size,
                num_epochs):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print('Using device:', device)
    # train a GPT model with num_layers
    model = PDEGPT(num_layers=num_layers)
    model = model.to(device)

    # build dataloader
    train_set = torch.utils.data.TensorDataset(torch.tensor(train_data, dtype=torch.float32))
    train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=4)

    test_set = torch.utils.data.TensorDataset(torch.tensor(test_data, dtype=torch.float32))
    test_loader = torch.utils.data.DataLoader(test_set, batch_size=8, shuffle=False, num_workers=4)

    optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=lr, total_steps=num_epochs*len(train_loader), final_div_factor=1e3)

    train_history = []
    test_history = []
    loss_buffer = []
    for epoch in range(num_epochs):
        model.train()
        for i, seq in enumerate(train_loader):
            seq = seq[0].to(device)
            optimizer.zero_grad()
            # training in block, not always using teacher forcing
            if i % 3 == 0:
                loss = 0
                ct = 0
                for b in range(0, seq.size(1)-20, 10):
                    pred = model.predict(seq[:, b:b+10], predict_steps=10, tstart=b)
                    loss += F.mse_loss(pred, seq[:, b+10:b+20])
                    ct += 1
                loss /= ct
            else:
                pred = model(seq[:, :-1])
                loss = F.mse_loss(pred, seq[:, 1:])
            loss.backward()
            optimizer.step()
            loss_buffer.append(loss.item())
            
            if i % 20 == 0:
                print("epoch %d, iter %d, loss %.3f" % (epoch, i, np.mean(loss_buffer)))
                loss_buffer = []
        train_history.append(loss.item())
        scheduler.step()

        model.eval()
        test_losses = []
        with torch.no_grad():
            for i, seq in enumerate(test_loader):
                seq = seq[0].to(device)
                pred = model.predict(seq[:, :10])
                loss = F.mse_loss(pred, seq[:, 10:])

                test_losses.append(loss.item())
        print("epoch %d, test loss %.3f" % (epoch, np.mean(test_losses)))
        test_history.append(np.mean(test_losses))

    return model, train_history, test_history


def eval_and_visualize(trained_model):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print('Using device:', device)
    test_set = torch.utils.data.TensorDataset(torch.tensor(test_data, dtype=torch.float32))
    test_loader = torch.utils.data.DataLoader(test_set, batch_size=8, shuffle=False, num_workers=4)

    trained_model.eval()
    test_losses = []
    with torch.no_grad():
        for i, seq in enumerate(test_loader):
            seq = seq[0].to(device)
            pred = trained_model.predict(seq[:, :10])
            loss = F.mse_loss(pred, seq[:, 10:])

            test_losses.append(loss.item())

        print('Final evaluation error:', np.mean(test_losses))

        # randomly pick a sample to evaluate and visualize
        seed_everything()
        idx = np.random.randint(0, len(test_data))
        seq = torch.tensor(test_data[idx:idx+1], dtype=torch.float32).to(device)
        pred = trained_model.predict(seq[:, :10])
        pred_seq = torch.cat((seq[:, :10], pred), dim=1).cpu().numpy()[0]

        plt.plot(np.linspace(0, 16, 100), seq.cpu().numpy()[0, -1], label='ground truth')
        plt.scatter(np.linspace(0, 16, 100), pred_seq[-1], label='prediction', c='g')
        plt.legend()
        plt.show()

    return

# %%
### you can change the hyperparameter of "train_a_gpt" to see how it affects the performance, please do not modify the other parts
### ==============================

torch.cuda.empty_cache()
# change the parameters to see how it affects the performance
model, train_history, test_history = train_a_gpt(lr=1e-3, num_layers=6, batch_size=24, num_epochs=100)
eval_and_visualize(model)

plt.plot(train_history, label='train loss')  # simply visualize the training loss
plt.plot(test_history, label='test loss')
plt.legend()
# Out:
# Using device: cpu
# Total number of trainable parameters: 1820324
# epoch 0, iter 0, loss 0.566
# epoch 0, iter 20, loss 0.552
# epoch 0, iter 40, loss 0.555
# epoch 0, iter 60, loss 0.554
# epoch 0, iter 80, loss 0.569
# epoch 0, test loss 0.644
# epoch 1, iter 0, loss 0.556
# epoch 1, iter 20, loss 0.544
# epoch 1, iter 40, loss 0.570
# epoch 1, iter 60, loss 0.588
# epoch 1, iter 80, loss 0.522
# epoch 1, test loss 0.642
# epoch 2, iter 0, loss 0.527
# epoch 2, iter 20, loss 0.551
# epoch 2, iter 40, loss 0.576
# epoch 2, iter 60, loss 0.518
# epoch 2, iter 80, loss 0.545
# epoch 2, test loss 0.619
# epoch 3, iter 0, loss 0.501
# epoch 3, iter 20, loss 0.518
# epoch 3, iter 40, loss 0.524
# epoch 3, iter 60, loss 0.492
# epoch 3, iter 80, loss 0.489
# epoch 3, test loss 0.577
# epoch 4, iter 0, loss 0.479
# epoch 4, iter 20, loss 0.470
# epoch 4, iter 40, loss 0.468
# epoch 4, iter 60, loss 0.465
# epoch 4, iter 80, loss 0.480
# epoch 4, test loss 0.546
# epoch 5, iter 0, loss 0.452
# epoch 5, iter 20, loss 0.461
# epoch 5, iter 40, loss 0.438
# epoch 5, iter 60, loss 0.445
# epoch 5, iter 80, loss 0.414
# epoch 5, test loss 0.506
# epoch 6, iter 0, loss 0.422
# epoch 6, iter 20, loss 0.406
# epoch 6, iter 40, loss 0.402
# epoch 6, iter 60, loss 0.415
# epoch 6, iter 80, loss 0.393
# epoch 6, test loss 0.469
# epoch 7, iter 0, loss 0.353
# epoch 7, iter 20, loss 0.358
# epoch 7, iter 40, loss 0.404
# epoch 7, iter 60, loss 0.349
# epoch 7, iter 80, loss 0.365
# epoch 7, test loss 0.429
# epoch 8, iter 0, loss 0.329
# epoch 8, iter 20, loss 0.347
# epoch 8, iter 40, loss 0.348
# epoch 8, iter 60, loss 0.310
# epoch 8, iter 80, loss 0.308
# epoch 8, test loss 0.380
# epoch 9, iter 0, loss 0.295
# epoch 9, iter 20, loss 0.317
# epoch 9, iter 40, loss 0.284
# epoch 9, iter 60, loss 0.269
# epoch 9, iter 80, loss 0.271
# epoch 9, test loss 0.333
# epoch 10, iter 0, loss 0.264
# epoch 10, iter 20, loss 0.276
# epoch 10, iter 40, loss 0.238
# epoch 10, iter 60, loss 0.238
# epoch 10, iter 80, loss 0.235
# epoch 10, test loss 0.290
# epoch 11, iter 0, loss 0.206
# epoch 11, iter 20, loss 0.218
# epoch 11, iter 40, loss 0.216
# epoch 11, iter 60, loss 0.200
# epoch 11, iter 80, loss 0.199
# epoch 11, test loss 0.249
# epoch 12, iter 0, loss 0.174
# epoch 12, iter 20, loss 0.195
# epoch 12, iter 40, loss 0.168
# epoch 12, iter 60, loss 0.174
# epoch 12, iter 80, loss 0.161
# epoch 12, test loss 0.218
# epoch 13, iter 0, loss 0.169
# epoch 13, iter 20, loss 0.163
# epoch 13, iter 40, loss 0.144
# epoch 13, iter 60, loss 0.137
# epoch 13, iter 80, loss 0.145
# epoch 13, test loss 0.189
# epoch 14, iter 0, loss 0.126
# epoch 14, iter 20, loss 0.131
# epoch 14, iter 40, loss 0.124
# epoch 14, iter 60, loss 0.124
# epoch 14, iter 80, loss 0.115
# epoch 14, test loss 0.162
# epoch 15, iter 0, loss 0.124
# epoch 15, iter 20, loss 0.107
# epoch 15, iter 40, loss 0.108
# epoch 15, iter 60, loss 0.105
# epoch 15, iter 80, loss 0.097
# epoch 15, test loss 0.144
# epoch 16, iter 0, loss 0.092
# epoch 16, iter 20, loss 0.099
# epoch 16, iter 40, loss 0.090
# epoch 16, iter 60, loss 0.089
# epoch 16, iter 80, loss 0.079
# epoch 16, test loss 0.124
# epoch 17, iter 0, loss 0.079
# epoch 17, iter 20, loss 0.082
# epoch 17, iter 40, loss 0.079
# epoch 17, iter 60, loss 0.072
# epoch 17, iter 80, loss 0.067
# epoch 17, test loss 0.113
# epoch 18, iter 0, loss 0.074
# epoch 18, iter 20, loss 0.067
# epoch 18, iter 40, loss 0.070
# epoch 18, iter 60, loss 0.063
# epoch 18, iter 80, loss 0.065
# epoch 18, test loss 0.100
# epoch 19, iter 0, loss 0.049
# epoch 19, iter 20, loss 0.059
# epoch 19, iter 40, loss 0.056
# epoch 19, iter 60, loss 0.055
# epoch 19, iter 80, loss 0.059
# epoch 19, test loss 0.090
# epoch 20, iter 0, loss 0.045
# epoch 20, iter 20, loss 0.047
# epoch 20, iter 40, loss 0.052
# epoch 20, iter 60, loss 0.058
# epoch 20, iter 80, loss 0.046
# epoch 20, test loss 0.082
# epoch 21, iter 0, loss 0.045
# epoch 21, iter 20, loss 0.045
# epoch 21, iter 40, loss 0.051
# epoch 21, iter 60, loss 0.043
# epoch 21, iter 80, loss 0.043
# epoch 21, test loss 0.082
# epoch 22, iter 0, loss 0.051
# epoch 22, iter 20, loss 0.044
# epoch 22, iter 40, loss 0.042
# epoch 22, iter 60, loss 0.043
# epoch 22, iter 80, loss 0.039
# epoch 22, test loss 0.072
# epoch 23, iter 0, loss 0.025
# epoch 23, iter 20, loss 0.035
# epoch 23, iter 40, loss 0.038
# epoch 23, iter 60, loss 0.037
# epoch 23, iter 80, loss 0.042
# epoch 23, test loss 0.070
# epoch 24, iter 0, loss 0.045
# epoch 24, iter 20, loss 0.034
# epoch 24, iter 40, loss 0.035
# epoch 24, iter 60, loss 0.036
# epoch 24, iter 80, loss 0.037
# epoch 24, test loss 0.078
# epoch 25, iter 0, loss 0.029
# epoch 25, iter 20, loss 0.037
# epoch 25, iter 40, loss 0.034
# epoch 25, iter 60, loss 0.032
# epoch 25, iter 80, loss 0.033
# epoch 25, test loss 0.062
# epoch 26, iter 0, loss 0.038
# epoch 26, iter 20, loss 0.031
# epoch 26, iter 40, loss 0.032
# epoch 26, iter 60, loss 0.032
# epoch 26, iter 80, loss 0.030
# epoch 26, test loss 0.062
# epoch 27, iter 0, loss 0.025
# epoch 27, iter 20, loss 0.032
# epoch 27, iter 40, loss 0.029
# epoch 27, iter 60, loss 0.029
# epoch 27, iter 80, loss 0.030
# epoch 27, test loss 0.059
# epoch 28, iter 0, loss 0.030
# epoch 28, iter 20, loss 0.030
# epoch 28, iter 40, loss 0.026
# epoch 28, iter 60, loss 0.028
# epoch 28, iter 80, loss 0.028
# epoch 28, test loss 0.053
# epoch 29, iter 0, loss 0.030
# epoch 29, iter 20, loss 0.026
# epoch 29, iter 40, loss 0.027
# epoch 29, iter 60, loss 0.030
# epoch 29, iter 80, loss 0.024
# epoch 29, test loss 0.056
# epoch 30, iter 0, loss 0.031
# epoch 30, iter 20, loss 0.028
# epoch 30, iter 40, loss 0.027
# epoch 30, iter 60, loss 0.025
# epoch 30, iter 80, loss 0.024
# epoch 30, test loss 0.053
# epoch 31, iter 0, loss 0.022
# epoch 31, iter 20, loss 0.026
# epoch 31, iter 40, loss 0.023
# epoch 31, iter 60, loss 0.026
# epoch 31, iter 80, loss 0.026
# epoch 31, test loss 0.060
# epoch 32, iter 0, loss 0.025
# epoch 32, iter 20, loss 0.024
# epoch 32, iter 40, loss 0.026
# epoch 32, iter 60, loss 0.021
# epoch 32, iter 80, loss 0.025
# epoch 32, test loss 0.049
# epoch 33, iter 0, loss 0.019
# epoch 33, iter 20, loss 0.025
# epoch 33, iter 40, loss 0.023
# epoch 33, iter 60, loss 0.022
# epoch 33, iter 80, loss 0.024
# epoch 33, test loss 0.051
# epoch 34, iter 0, loss 0.019
# epoch 34, iter 20, loss 0.024
# epoch 34, iter 40, loss 0.021
# epoch 34, iter 60, loss 0.026
# epoch 34, iter 80, loss 0.021
# epoch 34, test loss 0.045
# epoch 35, iter 0, loss 0.017
# epoch 35, iter 20, loss 0.021
# epoch 35, iter 40, loss 0.022
# epoch 35, iter 60, loss 0.023
# epoch 35, iter 80, loss 0.020
# epoch 35, test loss 0.044
# epoch 36, iter 0, loss 0.027
# epoch 36, iter 20, loss 0.024
# epoch 36, iter 40, loss 0.020
# epoch 36, iter 60, loss 0.019
# epoch 36, iter 80, loss 0.020
# epoch 36, test loss 0.048
# epoch 37, iter 0, loss 0.018
# epoch 37, iter 20, loss 0.023
# epoch 37, iter 40, loss 0.019
# epoch 37, iter 60, loss 0.020
# epoch 37, iter 80, loss 0.021
# epoch 37, test loss 0.047
# epoch 38, iter 0, loss 0.021
# epoch 38, iter 20, loss 0.018
# epoch 38, iter 40, loss 0.021
# epoch 38, iter 60, loss 0.018
# epoch 38, iter 80, loss 0.021
# epoch 38, test loss 0.046
# epoch 39, iter 0, loss 0.026
# epoch 39, iter 20, loss 0.020
# epoch 39, iter 40, loss 0.019
# epoch 39, iter 60, loss 0.017
# epoch 39, iter 80, loss 0.022
# epoch 39, test loss 0.040
# epoch 40, iter 0, loss 0.016
# epoch 40, iter 20, loss 0.020
# epoch 40, iter 40, loss 0.019
# epoch 40, iter 60, loss 0.019
# epoch 40, iter 80, loss 0.017
# epoch 40, test loss 0.045
# epoch 41, iter 0, loss 0.015
# epoch 41, iter 20, loss 0.019
# epoch 41, iter 40, loss 0.019
# epoch 41, iter 60, loss 0.016
# epoch 41, iter 80, loss 0.019
# epoch 41, test loss 0.042
# epoch 42, iter 0, loss 0.021
# epoch 42, iter 20, loss 0.020
# epoch 42, iter 40, loss 0.020
# epoch 42, iter 60, loss 0.017
# epoch 42, iter 80, loss 0.015
# epoch 42, test loss 0.045
# epoch 43, iter 0, loss 0.016
# epoch 43, iter 20, loss 0.018
# epoch 43, iter 40, loss 0.018
# epoch 43, iter 60, loss 0.017
# epoch 43, iter 80, loss 0.019
# epoch 43, test loss 0.057
# epoch 44, iter 0, loss 0.015
# epoch 44, iter 20, loss 0.022
# epoch 44, iter 40, loss 0.018
# epoch 44, iter 60, loss 0.017
# epoch 44, iter 80, loss 0.016
# epoch 44, test loss 0.039
# epoch 45, iter 0, loss 0.013
# epoch 45, iter 20, loss 0.018
# epoch 45, iter 40, loss 0.017
# epoch 45, iter 60, loss 0.015
# epoch 45, iter 80, loss 0.018
# epoch 45, test loss 0.039
# epoch 46, iter 0, loss 0.014
# epoch 46, iter 20, loss 0.015
# epoch 46, iter 40, loss 0.017
# epoch 46, iter 60, loss 0.018
# epoch 46, iter 80, loss 0.017
# epoch 46, test loss 0.049
# epoch 47, iter 0, loss 0.022
# epoch 47, iter 20, loss 0.016
# epoch 47, iter 40, loss 0.015
# epoch 47, iter 60, loss 0.018
# epoch 47, iter 80, loss 0.016
# epoch 47, test loss 0.042
# epoch 48, iter 0, loss 0.012
# epoch 48, iter 20, loss 0.017
# epoch 48, iter 40, loss 0.016
# epoch 48, iter 60, loss 0.016
# epoch 48, iter 80, loss 0.016
# epoch 48, test loss 0.038
# epoch 49, iter 0, loss 0.012
# epoch 49, iter 20, loss 0.018
# epoch 49, iter 40, loss 0.015
# epoch 49, iter 60, loss 0.018
# epoch 49, iter 80, loss 0.017
# epoch 49, test loss 0.039
# epoch 50, iter 0, loss 0.012
# epoch 50, iter 20, loss 0.018
# epoch 50, iter 40, loss 0.015
# epoch 50, iter 60, loss 0.016
# epoch 50, iter 80, loss 0.014
# epoch 50, test loss 0.036
# epoch 51, iter 0, loss 0.014
# epoch 51, iter 20, loss 0.016
# epoch 51, iter 40, loss 0.017
# epoch 51, iter 60, loss 0.016
# epoch 51, iter 80, loss 0.016
# epoch 51, test loss 0.045
# epoch 52, iter 0, loss 0.015
# epoch 52, iter 20, loss 0.015
# epoch 52, iter 40, loss 0.016
# epoch 52, iter 60, loss 0.016
# epoch 52, iter 80, loss 0.014
# epoch 52, test loss 0.037
# epoch 53, iter 0, loss 0.017
# epoch 53, iter 20, loss 0.017
# epoch 53, iter 40, loss 0.014
# epoch 53, iter 60, loss 0.015
# epoch 53, iter 80, loss 0.014
# epoch 53, test loss 0.043
# epoch 54, iter 0, loss 0.016
# epoch 54, iter 20, loss 0.015
# epoch 54, iter 40, loss 0.014
# epoch 54, iter 60, loss 0.014
# epoch 54, iter 80, loss 0.015
# epoch 54, test loss 0.034
# epoch 55, iter 0, loss 0.012
# epoch 55, iter 20, loss 0.014
# epoch 55, iter 40, loss 0.015
# epoch 55, iter 60, loss 0.014
# epoch 55, iter 80, loss 0.014
# epoch 55, test loss 0.034
# epoch 56, iter 0, loss 0.013
# epoch 56, iter 20, loss 0.015
# epoch 56, iter 40, loss 0.014
# epoch 56, iter 60, loss 0.015
# epoch 56, iter 80, loss 0.015
# epoch 56, test loss 0.038
# epoch 57, iter 0, loss 0.013
# epoch 57, iter 20, loss 0.016
# epoch 57, iter 40, loss 0.015
# epoch 57, iter 60, loss 0.014
# epoch 57, iter 80, loss 0.013
# epoch 57, test loss 0.045
# epoch 58, iter 0, loss 0.016
# epoch 58, iter 20, loss 0.014
# epoch 58, iter 40, loss 0.016
# epoch 58, iter 60, loss 0.013
# epoch 58, iter 80, loss 0.015
# epoch 58, test loss 0.033
# epoch 59, iter 0, loss 0.011
# epoch 59, iter 20, loss 0.014
# epoch 59, iter 40, loss 0.014
# epoch 59, iter 60, loss 0.014
# epoch 59, iter 80, loss 0.015
# epoch 59, test loss 0.039
# epoch 60, iter 0, loss 0.017
# epoch 60, iter 20, loss 0.014
# epoch 60, iter 40, loss 0.012
# epoch 60, iter 60, loss 0.013
# epoch 60, iter 80, loss 0.015
# epoch 60, test loss 0.033
# epoch 61, iter 0, loss 0.016
# epoch 61, iter 20, loss 0.015
# epoch 61, iter 40, loss 0.014
# epoch 61, iter 60, loss 0.014
# epoch 61, iter 80, loss 0.012
# epoch 61, test loss 0.032
# epoch 62, iter 0, loss 0.011
# epoch 62, iter 20, loss 0.014
# epoch 62, iter 40, loss 0.013
# epoch 62, iter 60, loss 0.013
# epoch 62, iter 80, loss 0.013
# epoch 62, test loss 0.033
# epoch 63, iter 0, loss 0.008
# epoch 63, iter 20, loss 0.014
# epoch 63, iter 40, loss 0.012
# epoch 63, iter 60, loss 0.014
# epoch 63, iter 80, loss 0.016
# epoch 63, test loss 0.056
# epoch 64, iter 0, loss 0.019
# epoch 64, iter 20, loss 0.014
# epoch 64, iter 40, loss 0.014
# epoch 64, iter 60, loss 0.014
# epoch 64, iter 80, loss 0.014
# epoch 64, test loss 0.031
# epoch 65, iter 0, loss 0.013
# epoch 65, iter 20, loss 0.013
# epoch 65, iter 40, loss 0.013
# epoch 65, iter 60, loss 0.012
# epoch 65, iter 80, loss 0.013
# epoch 65, test loss 0.034
# epoch 66, iter 0, loss 0.019
# epoch 66, iter 20, loss 0.014
# epoch 66, iter 40, loss 0.013
# epoch 66, iter 60, loss 0.013
# epoch 66, iter 80, loss 0.013
# epoch 66, test loss 0.036
# epoch 67, iter 0, loss 0.009
# epoch 67, iter 20, loss 0.015
# epoch 67, iter 40, loss 0.012
# epoch 67, iter 60, loss 0.013
# epoch 67, iter 80, loss 0.013
# epoch 67, test loss 0.039
# epoch 68, iter 0, loss 0.012
# epoch 68, iter 20, loss 0.014
# epoch 68, iter 40, loss 0.015
# epoch 68, iter 60, loss 0.015
# epoch 68, iter 80, loss 0.017
# epoch 68, test loss 0.062
# epoch 69, iter 0, loss 0.019
# epoch 69, iter 20, loss 0.017
# epoch 69, iter 40, loss 0.014
# epoch 69, iter 60, loss 0.014
# epoch 69, iter 80, loss 0.013
# epoch 69, test loss 0.036
# epoch 70, iter 0, loss 0.014
# epoch 70, iter 20, loss 0.012
# epoch 70, iter 40, loss 0.013
# epoch 70, iter 60, loss 0.013
# epoch 70, iter 80, loss 0.012
# epoch 70, test loss 0.029
# epoch 71, iter 0, loss 0.013
# epoch 71, iter 20, loss 0.012
# epoch 71, iter 40, loss 0.013
# epoch 71, iter 60, loss 0.010
# epoch 71, iter 80, loss 0.014
# epoch 71, test loss 0.028
# epoch 72, iter 0, loss 0.014
# epoch 72, iter 20, loss 0.013
# epoch 72, iter 40, loss 0.011
# epoch 72, iter 60, loss 0.012
# epoch 72, iter 80, loss 0.014
# epoch 72, test loss 0.027
# epoch 73, iter 0, loss 0.011
# epoch 73, iter 20, loss 0.011
# epoch 73, iter 40, loss 0.014
# epoch 73, iter 60, loss 0.013
# epoch 73, iter 80, loss 0.012
# epoch 73, test loss 0.029
# epoch 74, iter 0, loss 0.011
# epoch 74, iter 20, loss 0.012
# epoch 74, iter 40, loss 0.013
# epoch 74, iter 60, loss 0.012
# epoch 74, iter 80, loss 0.012
# epoch 74, test loss 0.028
# epoch 75, iter 0, loss 0.010
# epoch 75, iter 20, loss 0.012
# epoch 75, iter 40, loss 0.012
# epoch 75, iter 60, loss 0.012
# epoch 75, iter 80, loss 0.012
# epoch 75, test loss 0.037
# epoch 76, iter 0, loss 0.008
# epoch 76, iter 20, loss 0.012
# epoch 76, iter 40, loss 0.013
# epoch 76, iter 60, loss 0.013
# epoch 76, iter 80, loss 0.012
# epoch 76, test loss 0.031
# epoch 77, iter 0, loss 0.013
# epoch 77, iter 20, loss 0.014
# epoch 77, iter 40, loss 0.011
# epoch 77, iter 60, loss 0.012
# epoch 77, iter 80, loss 0.012
# epoch 77, test loss 0.031
# epoch 78, iter 0, loss 0.013
# epoch 78, iter 20, loss 0.013
# epoch 78, iter 40, loss 0.012
# epoch 78, iter 60, loss 0.011
# epoch 78, iter 80, loss 0.011
# epoch 78, test loss 0.028
# epoch 79, iter 0, loss 0.011
# epoch 79, iter 20, loss 0.012
# epoch 79, iter 40, loss 0.011
# epoch 79, iter 60, loss 0.012
# epoch 79, iter 80, loss 0.014
# epoch 79, test loss 0.030
# epoch 80, iter 0, loss 0.012
# epoch 80, iter 20, loss 0.011
# epoch 80, iter 40, loss 0.011
# epoch 80, iter 60, loss 0.012
# epoch 80, iter 80, loss 0.013
# epoch 80, test loss 0.025
# epoch 81, iter 0, loss 0.010
# epoch 81, iter 20, loss 0.011
# epoch 81, iter 40, loss 0.010
# epoch 81, iter 60, loss 0.013
# epoch 81, iter 80, loss 0.013
# epoch 81, test loss 0.034
# epoch 82, iter 0, loss 0.012
# epoch 82, iter 20, loss 0.013
# epoch 82, iter 40, loss 0.012
# epoch 82, iter 60, loss 0.011
# epoch 82, iter 80, loss 0.013
# epoch 82, test loss 0.030
# epoch 83, iter 0, loss 0.009
# epoch 83, iter 20, loss 0.013
# epoch 83, iter 40, loss 0.014
# epoch 83, iter 60, loss 0.016
# epoch 83, iter 80, loss 0.018
# epoch 83, test loss 0.082
# epoch 84, iter 0, loss 0.018
# epoch 84, iter 20, loss 0.016
# epoch 84, iter 40, loss 0.022
# epoch 84, iter 60, loss 0.018
# epoch 84, iter 80, loss 0.014
# epoch 84, test loss 0.032
# epoch 85, iter 0, loss 0.011
# epoch 85, iter 20, loss 0.013
# epoch 85, iter 40, loss 0.011
# epoch 85, iter 60, loss 0.010
# epoch 85, iter 80, loss 0.013
# epoch 85, test loss 0.024
# epoch 86, iter 0, loss 0.008
# epoch 86, iter 20, loss 0.010
# epoch 86, iter 40, loss 0.011
# epoch 86, iter 60, loss 0.010
# epoch 86, iter 80, loss 0.011
# epoch 86, test loss 0.024
# epoch 87, iter 0, loss 0.011
# epoch 87, iter 20, loss 0.012
# epoch 87, iter 40, loss 0.009
# epoch 87, iter 60, loss 0.012
# epoch 87, iter 80, loss 0.011
# epoch 87, test loss 0.027
# epoch 88, iter 0, loss 0.012
# epoch 88, iter 20, loss 0.010
# epoch 88, iter 40, loss 0.011
# epoch 88, iter 60, loss 0.011
# epoch 88, iter 80, loss 0.013
# epoch 88, test loss 0.026
# epoch 89, iter 0, loss 0.010
# epoch 89, iter 20, loss 0.010
# epoch 89, iter 40, loss 0.010
# epoch 89, iter 60, loss 0.012
# epoch 89, iter 80, loss 0.011
# epoch 89, test loss 0.030
# epoch 90, iter 0, loss 0.011
# epoch 90, iter 20, loss 0.012
# epoch 90, iter 40, loss 0.010
# epoch 90, iter 60, loss 0.011
# epoch 90, iter 80, loss 0.011
# epoch 90, test loss 0.023
# epoch 91, iter 0, loss 0.008
# epoch 91, iter 20, loss 0.011
# epoch 91, iter 40, loss 0.010
# epoch 91, iter 60, loss 0.011
# epoch 91, iter 80, loss 0.012
# epoch 91, test loss 0.028
# epoch 92, iter 0, loss 0.008
# epoch 92, iter 20, loss 0.011
# epoch 92, iter 40, loss 0.010
# epoch 92, iter 60, loss 0.010
# epoch 92, iter 80, loss 0.011
# epoch 92, test loss 0.026
# epoch 93, iter 0, loss 0.012
# epoch 93, iter 20, loss 0.010
# epoch 93, iter 40, loss 0.012
# epoch 93, iter 60, loss 0.010
# epoch 93, iter 80, loss 0.011
# epoch 93, test loss 0.046
# epoch 94, iter 0, loss 0.013
# epoch 94, iter 20, loss 0.012
# epoch 94, iter 40, loss 0.013
# epoch 94, iter 60, loss 0.014
# epoch 94, iter 80, loss 0.012
# epoch 94, test loss 0.033
# epoch 95, iter 0, loss 0.008
# epoch 95, iter 20, loss 0.011
# epoch 95, iter 40, loss 0.010
# epoch 95, iter 60, loss 0.011
# epoch 95, iter 80, loss 0.011
# epoch 95, test loss 0.024
# epoch 96, iter 0, loss 0.012
# epoch 96, iter 20, loss 0.011
# epoch 96, iter 40, loss 0.012
# epoch 96, iter 60, loss 0.011
# epoch 96, iter 80, loss 0.012
# epoch 96, test loss 0.033
# epoch 97, iter 0, loss 0.008
# epoch 97, iter 20, loss 0.013
# epoch 97, iter 40, loss 0.013
# epoch 97, iter 60, loss 0.014
# epoch 97, iter 80, loss 0.011
# epoch 97, test loss 0.036
# epoch 98, iter 0, loss 0.010
# epoch 98, iter 20, loss 0.012
# epoch 98, iter 40, loss 0.011
# epoch 98, iter 60, loss 0.010
# epoch 98, iter 80, loss 0.011
# epoch 98, test loss 0.028
# epoch 99, iter 0, loss 0.009
# epoch 99, iter 20, loss 0.011
# epoch 99, iter 40, loss 0.011
# epoch 99, iter 60, loss 0.010
# epoch 99, iter 80, loss 0.009
# epoch 99, test loss 0.027
# Using device: cpu
# Final evaluation error: 0.02673880977090448
